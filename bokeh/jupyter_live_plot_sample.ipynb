# %%
from jupyter_live_plot import JupyterLivePlot

# %%
my_plot = JupyterLivePlot(plot_width=800, plot_height=410)
my_plot.width_d = 500
my_plot.width_drop = 100
# Out:
# Create plot
# - width: 800 px
# - height: 410 px
#   <div class="bk-root" id="c0e097d6-4eda-407c-8c3a-b78abe106fc2" data-root-id="59360"></div>
# del line dummy
# dummy_glyph

# %%
from data_factory import DataFactory

# %%
my_plots=DataFactory(n=2)
print( my_plots.produce_data(0) )
# Out:
# do it, big time!
# Shuffle all lists, this way iterating over
# them has the same result as random choice.
# return dictionary with data
# {'humidity': array([-5.20107144]), 'temperature': array([1.62786009])}

# %%
import time

dt = 0.01
for i in range(200):
    my_plot.push_d( my_plots.produce_data(my_plot._x) )
    time.sleep(dt)
    
my_plots=DataFactory(n=5)  

for i in range(200):
    my_plot.push_d( my_plots.produce_data(my_plot._x) )
    time.sleep(dt)

my_plots=DataFactory(n=1)

for i in range(800):
    my_plot.push_d( my_plots.produce_data(my_plot._x) )
    time.sleep(dt)
# Out:
# return dictionary with data
# {'humidity': array([1.3834311]), 'temperature': array([3.25630297]), 'x': array([340.1]), 'pressure': array([nan])}
# return dictionary with data
# {'humidity': array([0.6281446]), 'temperature': array([3.61808294]), 'x': array([340.2]), 'pressure': array([nan])}
# return dictionary with data
# {'humidity': array([1.90763399]), 'temperature': array([3.740064]), 'x': array([340.3]), 'pressure': array([nan])}
# return dictionary with data
# {'humidity': array([2.62888088]), 'temperature': array([3.77526921]), 'x': array([340.4]), 'pressure': array([nan])}
# return dictionary with data
# {'humidity': array([2.4655697]), 'temperature': array([4.03386043]), 'x': array([340.5]), 'pressure': array([nan])}
# return dictionary with data
# {'humidity': array([3.59020937]), 'temperature': array([3.44526708]), 'x': array([340.6]), 'pressure': array([nan])}
# return dictionary with data
# ...
